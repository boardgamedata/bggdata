# %%
import seaborn as sb
import pandas as pd
import json

# %%
with open('C:\\temp\\da2_users.json') as data_file:    
     da2_users= json.load(data_file)

# %%
da2_users_table=pd.read_json(da2_users).transpose()
da2_game_table=pd.read_json(da2_users)

# %%
da2_game_table.head(5)
# Out:
#                            5Renton  Aecios  Anaskela  Awell  ChrisBlair  \
# Agricola                       8.0     2.0       NaN    NaN         7.0
# Caverna: The Cave Farmers      NaN     NaN       NaN    NaN         NaN
# Pandemic Legacy: Season 1      NaN     NaN       NaN    9.0         NaN
# Puerto Rico                    NaN     3.0       NaN    NaN         NaN
# Star Wars: Rebellion           NaN     6.0       NaN    NaN         NaN
#
#                            D0NK1J0T3  Greypilgrim  Ikarus  Koblar  LADER  \
# Agricola                         9.8          8.5     9.6     NaN    NaN
# Caverna: The Cave Farmers        NaN          NaN     9.0     NaN    NaN
# Pandemic Legacy: Season 1        NaN          NaN     NaN     NaN    NaN
# Puerto Rico                      9.8          8.0     NaN     9.0    NaN
# Star Wars: Rebellion             NaN          NaN     NaN     NaN    NaN
#
#                              ...     roblax  ryoga121  sandraynapi  \
# ...

# %%
da2_users_table.describe
# Out:
# <bound method NDFrame.describe of                 Agricola  Caverna: The Cave Farmers  \
# 5Renton             8.00                        NaN
# Aecios              2.00                        NaN
# Anaskela             NaN                        NaN
# Awell                NaN                        NaN
# ChrisBlair          7.00                        NaN
# D0NK1J0T3           9.80                        NaN
# Greypilgrim         8.50                        NaN
# Ikarus              9.60                        9.0
# Koblar               NaN                        NaN
# LADER                NaN                        NaN
# Lochi               8.00                        8.5
# Manu Chao           9.50                        NaN
# Michel13             NaN                        NaN
# Peto                7.00                        NaN
# Razmad              9.00                        NaN
# Renton              8.50                        NaN
# ...
